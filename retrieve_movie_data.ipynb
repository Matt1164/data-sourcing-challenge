# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
# Dependencies
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json

# %%
# Set environment variables from the .env in the local environment
load_dotenv()

nyt_api_key = os.getenv("NYT_API_KEY")
tmdb_api_key = os.getenv("TMDB_API_KEY")

# %% [markdown]
# ### Access the New York Times API

# %%
# Set the base URL
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Filter for movie reviews with "love" in the headline
# section_name should be "Movies"
# type_of_material should be "Review"
filter_query = 'section_name:"Movies" AND type_of_material:"Review" AND headline:"love"'

# Use a sort filter, sort by newest
sort = "newest"

# Select the following fields to return:
# headline, web_url, snippet, source, keywords, pub_date, byline, word_count
field_list = "headline,web_url,snippet,source,keywords,pub_date,byline,word_count"

# Search for reviews published between a begin and end date
begin_date = "20130101"
end_date = "20230531"

# Build URL
movie_data_url = f"{url}nyt_api_key={nyt_api_key}&fq={filter_query}&sort={sort}&fl={field_list}&begin_date={begin_date}&end_date={end_date}"
movie_data_url
# Out:
# 'https://api.nytimes.com/svc/search/v2/articlesearch.json?nyt_api_key=SXopIKwZrvDQWFSKAK90XBaaAvfFh5L2&fq=section_name:"Movies" AND type_of_material:"Review" AND headline:"love"&sort=newest&fl=headline,web_url,snippet,source,keywords,pub_date,byline,word_count&begin_date=20130101&end_date=20230531'

# %%
# Create an empty list to store the reviews
reviews_list = []

# loop through pages 0-19
for page in range(20):
    # create query with a page number
    movie_data_url_page = f"{url}api-key={nyt_api_key}&fq={filter_query}&sort={sort}&fl={field_list}&begin_date={begin_date}&end_date={end_date}&page={page}"
    
    # Send the GET request
    response = requests.get(movie_data_url_page)

    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        # Parse the JSON response
        data = response.json()
        
        # Extract the articles
        articles = data['response']['docs']
        
        # Process each article
        for article in articles:
            # Store the article headline and URL in a dictionary
            review = {
                'headline': article['headline']['main'],
                'url': article['web_url']
            }
            # Append the dictionary to the reviews_list
            reviews_list.append(review)
        
        # Print the page number that was just retrieved
        print(f"Page {page + 1} retrieved successfully.")
        
        # Add a twelve-second interval between queries to stay within API query limits
        time.sleep(12)
    
    elif response.status_code == 429:
        # Handle rate limiting (status code 429) by waiting for a minute and then retrying
        print("Rate limit exceeded. Waiting for a minute...")
        time.sleep(60)
        # Retry the same page
        page -= 1  # Retry the current page
    else:
        # Print an error message if the request was not successful
        print(f"Error: Unable to retrieve data for page {page + 1}")


# Print the reviews_list
print(reviews_list)

# Convert the list to a Pandas DataFrame
df_reviews = pd.DataFrame(reviews_list)

# Display basic information about the DataFrame
print(df_reviews.info())
# Out:
# Page 1 retrieved successfully.
# Page 2 retrieved successfully.
# Page 3 retrieved successfully.
# Page 4 retrieved successfully.
# Page 5 retrieved successfully.
# Page 6 retrieved successfully.
# Page 7 retrieved successfully.
# Page 8 retrieved successfully.
# Page 9 retrieved successfully.
# Page 10 retrieved successfully.
# Page 11 retrieved successfully.
# Page 12 retrieved successfully.
# Page 13 retrieved successfully.
# Page 14 retrieved successfully.
# Page 15 retrieved successfully.
# Page 16 retrieved successfully.
# Page 17 retrieved successfully.
# Page 18 retrieved successfully.
# Page 19 retrieved successfully.
# Page 20 retrieved successfully.
# [{'headline': '‘The Attachment Diaries’ Review: Love, Sick', 'url': 'https://www.nytimes.com/2023/05/25/movies/the-attachment-diaries-review.html'}, {'headline': 'Review: ‘What’s Love Got to Do With It?’ Probably a Lot', 'url': 'https://www.nytimes.com/2023/05/04/movies/whats-love-got-to-do-with-it-review.html'}, {'headline': '‘You Can Live Forever’ Review: Do You Love Me Now?', 'url': 'https://www.nytimes.com/2023/05/04/movies/you-can-live-forever-review.html'}, {'headline': '‘A Tourist’s Guide to Love’ Review: A Wearyingly Familiar Trip', 'url': 'https://www.nytimes.com/2023/04/21/movies/a-tourists-guide-to-love-review.html'}, {'headline': '‘Other People’s Children’ Review: True Romance', 'url': 'https://www.nytimes.com/2023/04/20/movies/other-peoples-children-review.html'}, {'headline': '‘One True Loves’ Review: A Romance Lost at Sea', 'url': 'https://www.nytimes.com/2023/04/13/movies/one-true-loves-movie-review.html'}, {'headline': '‘The Lost Weekend: A Love Story’ Review: When John Lennon Strayed', 'url': 'https://www.nytimes.com/2023/04/13/movies/the-lost-weekend-a-love-story-review.html'}, {'headline': '‘A Thousand and One’ Review: A New York Love Story', 'url': 'https://www.nytimes.com/2023/03/30/movies/a-thousand-and-one-review.html'}, {'headline': '‘Your Place or Mine’ Review: Try Neither', 'url': 'https://www.nytimes.com/2023/02/09/movies/your-place-or-mine-review.html'}, {'headline': '‘Love in the Time of Fentanyl’ Review: Heartbreak, Death and Hope in Vancouver', 'url': 'https://www.nytimes.com/2023/02/02/movies/love-in-the-time-of-fentanyl-review.html'}, {'headline': '‘Pamela, a Love Story’ Review: A Frank Look Back', 'url': 'https://www.nytimes.com/2023/01/31/movies/pamela-a-love-story-review.html'}, {'headline': '‘In From the Side’ Review: Love and Rugby Play a Losing Game', 'url': 'https://www.nytimes.com/2023/01/19/movies/in-from-the-side-review.html'}, {'headline': '‘After Love’ Review: The Other Woman', 'url': 'https://www.nytimes.com/2023/01/19/movies/after-love-review.html'}, {'headline': '‘Alcarràs’ Review: Labor of Love', 'url': 'https://www.nytimes.com/2023/01/05/movies/alcarras-review.html'}, {'headline': '‘Nelly & Nadine’ Review: An Unlikely Love, an Unlikely Record', 'url': 'https://www.nytimes.com/2022/12/15/movies/nelly-and-nadine-review.html'}, {'headline': '‘Lady Chatterley’s Lover’ Review: When Connie Met Ollie', 'url': 'https://www.nytimes.com/2022/12/01/movies/lady-chatterleys-lover-review.html'}, {'headline': '‘The Sound of Christmas’ Review: A Gospel Singer Finds Love', 'url': 'https://www.nytimes.com/2022/11/23/movies/sound-of-christmas-review.html'}, {'headline': '‘The Inspection’ Review: Boot Camp, a Love Story', 'url': 'https://www.nytimes.com/2022/11/17/movies/the-inspection-review-boot-camp-a-love-story.html'}, {'headline': '‘Bones and All’ Review: You Eat What You Are', 'url': 'https://www.nytimes.com/2022/11/17/movies/bones-and-all-review.html'}, {'headline': '‘My Policeman’ Review: Two Love Affairs, Equally Tragic', 'url': 'https://www.nytimes.com/2022/10/20/movies/my-policeman-review.html'}, {'headline': '‘About Fate’ Review: Love the One You’re With?', 'url': 'https://www.nytimes.com/2022/09/08/movies/about-fate-review.html'}, {'headline': '‘Waiting for Bojangles’ Review: Endless Love', 'url': 'https://www.nytimes.com/2022/09/01/movies/waiting-for-bojangles-review-endless-love.html'}, {'headline': '‘I Love My Dad’ Review: A Father Catfishes His Son', 'url': 'https://www.nytimes.com/2022/08/04/movies/i-love-my-dad-review.html'}, {'headline': '‘A Love Song’ Review: When Moving Forward Means Looking Back', 'url': 'https://www.nytimes.com/2022/07/28/movies/a-love-song-review.html'}, {'headline': '‘Alone Together’ Review: Finding Love in a Pandemic Retreat', 'url': 'https://www.nytimes.com/2022/07/21/movies/alone-together-review.html'}, {'headline': '‘Art of Love’ Review: An Erotic Male Fantasy in Puerto Rico', 'url': 'https://www.nytimes.com/2022/07/21/movies/art-of-love-review.html' ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   headline  200 non-null    object
#  1   url       200 non-null    object
# dtypes: object(2)
# memory usage: 3.3+ KB
# None

# %%
df_reviews.info()
# Out:
#                                               headline  \
# 0          ‘The Attachment Diaries’ Review: Love, Sick
# 1    Review: ‘What’s Love Got to Do With It?’ Proba...
# 2    ‘You Can Live Forever’ Review: Do You Love Me ...
# 3    ‘A Tourist’s Guide to Love’ Review: A Wearying...
# 4       ‘Other People’s Children’ Review: True Romance
# ..                                                 ...
# 195  Review: A Combustible Pair Find Love in ‘The O...
# 196  Review: Love as the World Wars, in ‘The Ottoma...
# 197  Review: It’s All Mirth and Taxes in ‘Love & Ta...
# 198  Review: ‘Everybody Loves Somebody,’ a Rom-Com ...
# 199  Review: Cute Cats of ‘Kedi,’ Rekindling a ‘Lov...
#
#                                                    url
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/what...
# 2    https://www.nytimes.com/2023/05/04/movies/you-...
# 3    https://www.nytimes.com/2023/04/21/movies/a-to...
# 4    https://www.nytimes.com/2023/04/20/movies/othe...
# ..                                                 ...
# 195  https://www.nytimes.com/2017/03/09/movies/the-...
# 196  https://www.nytimes.com/2017/03/09/movies/revi...
# 197  https://www.nytimes.com/2017/03/02/movies/love...
# 198  https://www.nytimes.com/2017/02/16/movies/ever...
# 199  https://www.nytimes.com/2017/02/09/movies/kedi...
#
# [200 rows x 2 columns]

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
# Assuming reviews_list is a list of dictionaries
first_5_results = reviews_list[:5]

# Use json.dumps to format the data with an indentation of 4 spaces
formatted_results = json.dumps(first_5_results, indent=4)

# Print the formatted results
print(formatted_results)
# Out:
# [
#     {
#         "headline": "\u2018The Attachment Diaries\u2019 Review: Love, Sick",
#         "url": "https://www.nytimes.com/2023/05/25/movies/the-attachment-diaries-review.html"
#     },
#     {
#         "headline": "Review: \u2018What\u2019s Love Got to Do With It?\u2019 Probably a Lot",
#         "url": "https://www.nytimes.com/2023/05/04/movies/whats-love-got-to-do-with-it-review.html"
#     },
#     {
#         "headline": "\u2018You Can Live Forever\u2019 Review: Do You Love Me Now?",
#         "url": "https://www.nytimes.com/2023/05/04/movies/you-can-live-forever-review.html"
#     },
#     {
#         "headline": "\u2018A Tourist\u2019s Guide to Love\u2019 Review: A Wearyingly Familiar Trip",
#         "url": "https://www.nytimes.com/2023/04/21/movies/a-tourists-guide-to-love-review.html"
#     },
#     {
#         "headline": "\u2018Other People\u2019s Children\u2019 Review: True Romance",
#         "url": "https://www.nytimes.com/2023/04/20/movies/other-peoples-children-review.html"
#     }
# ]

# %%
# Convert reviews_list to a Pandas DataFrame using json_normalize()
import pandas as pd
from pandas import json_normalize

# Assuming reviews_list is a list of dictionaries
df_reviews = json_normalize(reviews_list)

# Display the DataFrame
print(df_reviews)
# Out:
#                                               headline  \
# 0          ‘The Attachment Diaries’ Review: Love, Sick
# 1    Review: ‘What’s Love Got to Do With It?’ Proba...
# 2    ‘You Can Live Forever’ Review: Do You Love Me ...
# 3    ‘A Tourist’s Guide to Love’ Review: A Wearying...
# 4       ‘Other People’s Children’ Review: True Romance
# ..                                                 ...
# 195  Review: A Combustible Pair Find Love in ‘The O...
# 196  Review: Love as the World Wars, in ‘The Ottoma...
# 197  Review: It’s All Mirth and Taxes in ‘Love & Ta...
# 198  Review: ‘Everybody Loves Somebody,’ a Rom-Com ...
# 199  Review: Cute Cats of ‘Kedi,’ Rekindling a ‘Lov...
#
#                                                    url
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/what...
# 2    https://www.nytimes.com/2023/05/04/movies/you-...
# 3    https://www.nytimes.com/2023/04/21/movies/a-to...
# 4    https://www.nytimes.com/2023/04/20/movies/othe...
# ..                                                 ...
# 195  https://www.nytimes.com/2017/03/09/movies/the-...
# 196  https://www.nytimes.com/2017/03/09/movies/revi...
# 197  https://www.nytimes.com/2017/03/02/movies/love...
# 198  https://www.nytimes.com/2017/02/16/movies/ever...
# 199  https://www.nytimes.com/2017/02/09/movies/kedi...
#
# [200 rows x 2 columns]

# %%
# Extract the title from the "headline.main" column and
# save it to a new column "title"
# Title is between unicode characters \u2018 and \u2019. 
# End string should include " Review" to avoid cutting title early
df_reviews['title'] = df_reviews['headline'].str.extract(r'\u2018(.*?)(?:\u2019|$)').fillna('') + ' Review'

# Display the DataFrame
print(df_reviews[['headline', 'title']].head())
# Out:
#                                             headline  \
# 0        ‘The Attachment Diaries’ Review: Love, Sick
# 1  Review: ‘What’s Love Got to Do With It?’ Proba...
# 2  ‘You Can Live Forever’ Review: Do You Love Me ...
# 3  ‘A Tourist’s Guide to Love’ Review: A Wearying...
# 4     ‘Other People’s Children’ Review: True Romance
#
#                            title
# 0  The Attachment Diaries Review
# 1                    What Review
# 2    You Can Live Forever Review
# 3               A Tourist Review
# 4            Other People Review
#                                               headline  \
# 0          ‘The Attachment Diaries’ Review: Love, Sick
# 1    Review: ‘What’s Love Got to Do With It?’ Proba...
# 2    ‘You Can Live Forever’ Review: Do You Love Me ...
# 3    ‘A Tourist’s Guide to Love’ Review: A Wearying...
# 4       ‘Other People’s Children’ Review: True Romance
# ..                                                 ...
# 195  Review: A Combustible Pair Find Love in ‘The O...
# 196  Review: Love as the World Wars, in ‘The Ottoma...
# 197  Review: It’s All Mirth and Taxes in ‘Love & Ta...
# 198  Review: ‘Everybody Loves Somebody,’ a Rom-Com ...
# 199  Review: Cute Cats of ‘Kedi,’ Rekindling a ‘Lov...
#
#                                                    url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/what...
# 2    https://www.nytimes.com/2023/05/04/movies/you-...
# 3    https://www.nytimes.com/2023/04/21/movies/a-to...
# 4    https://www.nytimes.com/2023/04/20/movies/othe...
# ..                                                 ...
# 195  https://www.nytimes.com/2017/03/09/movies/the-...
# 196  https://www.nytimes.com/2017/03/09/movies/revi...
# 197  https://www.nytimes.com/2017/03/02/movies/love...
# 198  https://www.nytimes.com/2017/02/16/movies/ever...
# 199  https://www.nytimes.com/2017/02/09/movies/kedi...
#
#                                 title
# 0       The Attachment Diaries Review
# 1                         What Review
# 2         You Can Live Forever Review
# 3                    A Tourist Review
# 4                 Other People Review
# ..                                ...
# 195             The Other Half Review
# 196     The Ottoman Lieutenant Review
# 197               Love & Taxes Review
# 198  Everybody Loves Somebody, Review
# 199                      Kedi, Review
#
# [200 rows x 3 columns]

# %%
# Extract 'name' and 'value' from items in "title" column
def extract_title_info(title):
    try:
        extracted_title = title.split('’', 1)[0].split('‘', 1)[-1]
        return f"{extracted_title} Review"
    except:
        return None

# Apply the function to the "title" column
df_reviews['title'] = df_reviews['headline'].apply(extract_title_info)

# Display the DataFrame with the updated "title" column
print(df_reviews[['headline', 'url', 'title']].head())
# Out:
#                                             headline  \
# 0        ‘The Attachment Diaries’ Review: Love, Sick
# 1  Review: ‘What’s Love Got to Do With It?’ Proba...
# 2  ‘You Can Live Forever’ Review: Do You Love Me ...
# 3  ‘A Tourist’s Guide to Love’ Review: A Wearying...
# 4     ‘Other People’s Children’ Review: True Romance
#
#                                                  url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/what...
# 2  https://www.nytimes.com/2023/05/04/movies/you-...
# 3  https://www.nytimes.com/2023/04/21/movies/a-to...
# 4  https://www.nytimes.com/2023/04/20/movies/othe...
#
#                            title
# 0  The Attachment Diaries Review
# 1                    What Review
# 2    You Can Live Forever Review
# 3               A Tourist Review
# 4            Other People Review

# %%
# Create a list from the "title" column using to_list()
# These titles will be used in the query for The Movie Database
# Assuming df_reviews is your DataFrame
title_list = df_reviews['title'].to_list()

# Display the list of titles
print(title_list)
# Out:
# ['The Attachment Diaries Review', 'What Review', 'You Can Live Forever Review', 'A Tourist Review', 'Other People Review', 'One True Loves Review', 'The Lost Weekend: A Love Story Review', 'A Thousand and One Review', 'Your Place or Mine Review', 'Love in the Time of Fentanyl Review', 'Pamela, a Love Story Review', 'In From the Side Review', 'After Love Review', 'Alcarràs Review', 'Nelly & Nadine Review', 'Lady Chatterley Review', 'The Sound of Christmas Review', 'The Inspection Review', 'Bones and All Review', 'My Policeman Review', 'About Fate Review', 'Waiting for Bojangles Review', 'I Love My Dad Review', 'A Love Song Review', 'Alone Together Review', 'Art of Love Review', 'The Wheel Review', 'Thor: Love and Thunder Review', 'Both Sides of the Blade Review', 'Fire of Love Review', 'Love & Gelato Review', 'Stay Prayed Up Review', 'Benediction Review', 'Dinner in America Review', 'In a New York Minute Review', 'Anaïs in Love Review', 'I Love America Review', 'See You Then Review', 'La Mami Review', 'Love After Love Review', 'Deep Water Review', 'Lucy and Desi Review', 'Cyrano Review', 'The In Between Review', 'Book of Love Review', 'Lingui, the Sacred Bonds Review', 'The Pink Cloud Review', 'A Journal for Jordan Review', 'West Side Story Review', 'Aulcie Review', 'Love Is Love Is Love Review', 'Love Hard Review', 'Bergman Island Review', 'Hard Luck Love Song Review', 'South of Heaven Review', 'Wife of a Spy Review', 'Happier Than Ever Review', 'Together Review', 'Annette Review', 'Resort to Love Review', 'Woodstock 99: Peace, Love and Rage Review', 'Casanova, Last Love Review', 'Running Against the Wind Review', 'Asia Review', 'Undine Review', 'This Town Review', 'Tu Me Manques Review', 'Monday Review', 'Ride or Die Review', 'Future People Review', 'Luz Review', 'Happily Review', 'This Is the Life Review', 'To All the Boys: Always and Forever Review', 'Young Hearts Review', 'Little Fish Review', 'Two of Us Review', 'Atlantis Review', 'Preparations to Be Together Review', 'Your Name Engraved Herein Review', 'Sylvie Review', 'Ariana Grande: Excuse Me, I Love You Review', 'Museum Town Review', 'Wild Mountain Thyme Review', 'My Psychedelic Love Story Review', '69: The Saga of Danny Hernandez Review', 'Ammonite Review', 'Love and Monsters Review', 'Dick Johnson Is Dead Review', 'Love, Guaranteed Review', 'Feel the Beat Review', 'Babyteeth Review', 'Spelling the Dream Review', 'A Secret Love Review', 'Love Wedding Repeat Review', 'Almost Love Review', 'Hope Gap Review', 'All the Bright Places Review', 'The Photograph Review', 'You Go to My Head Review', 'Ordinary Love Review', 'To All the Boys: P.S. I Still Love You Review', 'The Woman Who Loves Giraffes Review', 'Queen & Slim Review', 'Marriage Story Review', 'Cyrano, My Love Review', 'Pretenders Review', 'First Love Review', 'Loro Review', 'Falling Inn Love Review', 'Hot Air Review', 'Love, Antosha Review', 'Leto Review', 'The Tomorrow Man Review', 'Asako I & II Review', 'The Sun Is Also a Star Review', 'Shéhérazade Review', 'Long Shot Review', 'Clara Review', 'Kalank Review', 'Rafiki Review', 'Diane Review', 'Five Feet Apart Review', 'Ash Is Purest White Review', 'Gloria Bell Review', 'Black Mother Review', 'The Hole in the Ground Review', 'How to Train Your Dragon: The Hidden World Review', 'A Tuba to Cuba Review', 'Fighting With My Family Review', 'Sorry Angel Review', 'Berlin, I Love You Review', 'Untogether Review', 'Cold War Review', 'If Beale Street Could Talk Review', 'Asher Review', 'The Party Review', 'The Great Pretender Review', 'Sicilian Ghost Story Review', 'The New Romantic Review', 'Pimp Review', 'In a Relationship Review', 'They Review', 'Burning, Review', 'After Everything, Review', 'Quincy Review', 'Love, Gilda, Review', 'Tea With the Dames, Review', 'Bel Canto, Review', 'The Citizen, Review', 'Love, Cecil, Review', 'How to Talk to Girls at Parties Review', 'Rogers Park, Review', 'Love & Bananas, Review', 'Review: If You Love Godard, You Review', 'Submergence, ...

# %% [markdown]
# ### Access The Movie Database API

# %%
TMDB_API_KEY = 'a67a85b6c6adc70be646faae9b9c1509'

# Prepare The Movie Database query
url = "https://api.themoviedb.org/3/search/movie?query="
tmdb_key_string = "&api_key=" + tmdb_api_key

# %%
import requests
import time

# Your TMDb API key
TMDB_API_KEY = 'a67a85b6c6adc70be646faae9b9c1509'  # Replace with your actual TMDb API key

# Create an empty list to store the results
tmdb_movies_list = []

# Create a request counter to sleep the requests after a multiple of 50 requests
request_counter = 0

# Loop through the titles
for title in df_reviews['title'].to_list():
    # Check if we need to sleep before making a request
    if request_counter > 0 and request_counter % 50 == 0:
        print(f"Sleeping for 10 seconds to avoid rate limit...")
        time.sleep(10)

    # Add 1 to the request counter
    request_counter += 1

    # Remove the word "Review" from the title
    title_for_search = title.replace('Review', '').strip()

    # Perform a "GET" request for The Movie Database
    url = f'https://api.themoviedb.org/3/search/movie?api_key={TMDB_API_KEY}&query={title_for_search}&include_adult=false'
    response = requests.get(url)

    try:
        # Include a try clause to search for the full movie details.
        # Use the except clause to print out a statement if a movie
        # is not found.
        response.raise_for_status()
        data = response.json()

        # Check if results list is not empty
        if data['results']:
            # Get movie id
            movie_id = data['results'][0]['id']

            # Make a request for the full movie details
            url = f'https://api.themoviedb.org/3/movie/{movie_id}?api_key={TMDB_API_KEY}&language=en-US'
            response = requests.get(url)

            # Extract relevant information and append it to the tmdb_movies_list
            movie_data = response.json()
            genres = [genre['name'] for genre in movie_data['genres']]
            languages = [lang['english_name'] for lang in movie_data['spoken_languages']]
            countries = [country['name'] for country in movie_data['production_countries']]
            tmdb_movies_list.append({
                'title': title,
                'genres': genres,
                'languages': languages,
                'countries': countries
            })

            print(f"Movie found: {title}")
        else:
            print(f"Movie not found: {title}")

    except requests.exceptions.HTTPError as err:
        print(f"Movie not found: {title}")
        print(f"Error: {err}")

# Display the list of movie details
print(tmdb_movies_list)
# Out:
# Movie found: The Attachment Diaries Review
# Movie found: What Review
# Movie found: You Can Live Forever Review
# Movie found: A Tourist Review
# Movie found: Other People Review
# Movie found: One True Loves Review
# Movie found: The Lost Weekend: A Love Story Review
# Movie found: A Thousand and One Review
# Movie found: Your Place or Mine Review
# Movie found: Love in the Time of Fentanyl Review
# Movie found: Pamela, a Love Story Review
# Movie found: In From the Side Review
# Movie found: After Love Review
# Movie found: Alcarràs Review
# Movie found: Nelly & Nadine Review
# Movie found: Lady Chatterley Review
# Movie found: The Sound of Christmas Review
# Movie found: The Inspection Review
# Movie found: Bones and All Review
# Movie found: My Policeman Review
# Movie found: About Fate Review
# Movie found: Waiting for Bojangles Review
# Movie found: I Love My Dad Review
# Movie found: A Love Song Review
# Movie found: Alone Together Review
# Movie found: Art of Love Review
# Movie found: The Wheel Review
# Movie found: Thor: Love and Thunder Review
# Movie found: Both Sides of the Blade Review
# Movie found: Fire of Love Review
# Movie found: Love & Gelato Review
# Movie found: Stay Prayed Up Review
# Movie found: Benediction Review
# Movie found: Dinner in America Review
# Movie found: In a New York Minute Review
# Movie found: Anaïs in Love Review
# Movie found: I Love America Review
# Movie found: See You Then Review
# Movie found: La Mami Review
# Movie found: Love After Love Review
# Movie found: Deep Water Review
# Movie found: Lucy and Desi Review
# Movie found: Cyrano Review
# Movie found: The In Between Review
# Movie found: Book of Love Review
# Movie found: Lingui, the Sacred Bonds Review
# Movie found: The Pink Cloud Review
# Movie found: A Journal for Jordan Review
# Movie found: West Side Story Review
# Movie not found: Aulcie Review
# Sleeping for 10 seconds to avoid rate limit...
# Movie found: Love Is Love Is Love Review
# Movie found: Love Hard Review
# Movie found: Bergman Island Review
# Movie found: Hard Luck Love Song Review
# Movie found: South of Heaven Review
# Movie found: Wife of a Spy Review
# Movie found: Happier Than Ever Review
# Movie found: Together Review
# Movie found: Annette Review
# Movie found: Resort to Love Review
# Movie found: Woodstock 99: Peace, Love and Rage Review
# Movie found: Casanova, Last Love Review
# Movie found: Running Against the Wind Review
# Movie found: Asia Review
# Movie found: Undine Review
# Movie found: This Town Review
# Movie found: Tu Me Manques Review
# Movie found: Monday Review
# Movie found: Ride or Die Review
# Movie found: Future People Review
# Movie found: Luz Review
# Movie found: Happily Review
# Movie found: This Is the Life Review
# Movie found: To All the Boys: Always and Forever Review
# Movie found: Young Hearts Review
# Movie found: Little Fish Review
# Movie found: Two of Us Review
# Movie found: Atlantis Review
# Movie found: Preparations to Be Together Review
# Movie found: Your Name Engraved Herein Review
# Movie found: Sylvie Review
# Movie found: Ariana Grande: Excuse Me, I Love You Review
# Movie found: Museum Town Review
# Movie found: Wild Mountain Thyme Review
# Movie found: My Psychedelic Love Story Review
# Movie found: 69: The Saga of Danny Hernandez Review
# Movie found: Ammonite Review
# Movie found: Love and Monsters Review
# Movie found: Dick Johnson Is Dead Review
# Movie found: Love, Guaranteed Review
# Movie found: Feel the Beat Review
# Movie found: Babyteeth Review
# Movie found: Spelling the Dream Review
# Movie found: A Secret Love Review
# Movie found: Love Wedding Repeat Review
# Movie found: Almost Love Review
# Movie found: Hope Gap Review
# Movie found: All the Bright Places Review
# Movie found: The Photograph Review
# Movie found: You Go to My Head Review
# Sleeping for 10 seconds to avoid rate limit...
# Movie found: Ordinary Love Review
# Movie found: To All the Boys: P.S. I Still Love You Review
# Movie found: The Woman Who Loves Giraffes Review
# Movie found: Queen & Slim Review
# Movie found: Marriage Story Review
# Movie found: Cyrano, My Love Review
# Movie found: Pretenders Review
# Movie found: First Love Review
# Movie found: Loro Review
# Movie found: Falling Inn Love Review
# Movie found: Hot Air Review
# Movie found: Love, Antosha Review
# Movie found: Leto Review
# Movie found: The Tomorrow Man Review
# Movie found: Asako I & II Review
# Movie found: The Sun Is Also a Star Review
# Movie found: Shéhérazade Review
# Movie found: Long Shot Review
# Movie found: Clara Review
# Movie found: Kalank Review
# Movie found: Rafiki Review
# Movie found: Diane Review
# Movie found: Five Feet Apart Review
# Movie found: Ash Is Purest White Review
# Movie found: Gloria Bell Review
# Movie found: Black Mother Review
# Movie found: The Hole in the Ground Review
# Movie found: How to Train Your Dragon: The Hidden World Review
# Movie found: A Tuba to Cuba Review
# Movie found: Fighting With My Family Review
# Movie found: Sorry Angel Review
# Movie found: Berlin, I Love You Review
# Movie found: Untogether Review
# Movie found: Cold War Review
# Movie found: If Beale Street Could Talk Review
# Movie found: Asher Review
# Movie found: The Party Review
# Movie found: The Great Pretender Review
# Movie found: Sicilian Ghost Story Review
# Movie found: The New Romantic Review
# Movie found: Pimp Review
# Movie found: In a Relationship Review
# Movie found: They Review
# Movie found: Burning, Review
# Movie found: After Everything, Review
# Movie found: Quincy Review
# Movie found: Love, Gilda, Review
# Movie found: Tea With the Dames, Review
# Movie found: Bel Canto, Review
# Movie found: The Citizen, Review
# Sleeping for 10 seconds to avoid rate limit...
# Movie found: Love, Cecil, Review
# Movie found: How to Talk to Girls at Parties Review
# Movie found: Rogers Park, Review
# Movie found: Love & Bananas, Review
# Movie not found: Review: If You Love Godard, You Review
# Movie found: Submergence, Review
# Movie found: Love After Love, Review
# Movie found: Outside In Review
# Movie found: Love, Simon, Review
# Movie found: Keep the Change, Review
# Movie found: The Party Review
# Movie found: The Housemaid, Review
# Movie found: Forever My Girl, Review
# Movie found: Kangaroo: A Love-Hate Story Review
# Movie found: Lover for a Day Review
# Movie found: Youth, Review
# Movie found: Killing for Love Review
# Movie found: The Shape of Water Review
# Movie found: Love Beats Rhymes, Review
# Movie found: Cuba and the Cameraman Review
# Movie found: On the Beach at Night Alone Review
# Movie found: Thelma, Review
# Movie found: Hello Again, Review
# Movie found: It Happened in L.A., Review
# Movie found: God Review
# Movie found: The Mountain Between Us Review
# Movie found: Dina, Review
# Movie found: In Search of Fellini Review
# Movie found: Woodpeckers, Review
# Movie found: I Do ... Until I Don Review
# Movie found: Tales of an Immoral Couple Review
# Movie found: After Love Review
# Movie not found: Review: Aid Workers in Love and War in Sean Penn Review
# Movie found: Women Who Kill, Review
# Movie found: False Confessions, Review
# Movie not found: Review: Those Movies, Himself — Bertrand Tavernier Review
# Movie found: The Big Sick, Review
# Movie found: Lost in Paris Review
# Movie found: Vincent N Roxxy, Review
# Movie found: Everything, Everything Review
# Movie found: Hounds of Love Review
# Movie found: Harold and Lillian Review
# Movie found: The Happiest Day in the Life of Olli Maki, Review
# Movie found: The Promise Review
# Movie found: Frantz, Review
# Movie found: The Other Half Review
# Movie found: The Ottoman Lieutenant Review
# Movie found: Review: It Review
# Movie found: Everybody Loves Somebody, Review
# Movie found: Kedi, Review
# [{'title': 'The Attachment Diaries Review', 'genres': ['Drama', 'Mystery', 'Thriller', 'Horror'], 'languages': ['Spanish'], 'countries': ['Argentina']}, {'title': 'What Review', 'genres': ['Comedy'], 'languages': [], 'countries': ['United States of America']}, {'title': 'You Can Live Forever Review', 'genres': ['Drama', 'Romance'], 'languages': ['English', 'French'], 'countries': ['Canada', 'United States of America']}, {'title': 'A Tourist Review', 'genres': ['Romance', 'Comedy'], 'languages': ['English', 'Vietnamese'], 'countries': ['United States of America']}, {'title': 'Other People Review', 'genres': ['Comedy', 'Drama'], 'languages': ['English'], 'countries': ['United States of America']}, {'title': 'One True Loves Review', 'genres': ['Romance', 'Drama', 'Comedy'], 'languages': ['English'], 'countries': ['Czech Republic', 'United States of America']}, {'title': 'The Lost Weekend: A Love Story Review', 'genres': ['Documentary'], 'languages': ['English'], 'countries': ['United States of America']}, {'title': 'A Thousand and One Review', 'genres': ['Drama', 'Crime'], 'languages': ['Spanish', 'English', 'Portuguese'], 'countries': ['United States of America']}, {'title': 'Your Place or Mine Review', 'genres': ['Romance', 'Comedy'], 'languages': ['English'], 'countries': ['United States of America']}, {'title': 'Love in the Time of Fentanyl Review', 'genres': ['Documentary'], 'languages': ['English'], 'countries': ['Canada', 'United States of America']}, {'title': 'Pamela, a Love Story Review', 'genres': ['Documentary'], 'languages': ['English'], 'countries': ['United States of America']}, {'title': 'In From the Side Review', 'genres': ['Drama', 'Romance'], 'languages': ['English'], 'countries': ['United Kingdom']}, {'title': 'After Love Review', 'genres': ['Drama'], 'languages': ['English', 'Arabic', 'French', 'Urdu'], 'countries': ['United Kingdom']}, {'title': 'Alcarràs Review', 'genres': ['Drama'], 'languages': ['Catalan'], 'countries': ['Spain']}, {'title': 'Nelly & Nadine Review', 'genres': ['Drama', 'Romance'], 'languages': ['French'], 'countries': ['Germany', 'France', 'Italy']}, {'title': 'Lady Chatterley Review', 'genres': ['Drama', 'Romance'], 'languages': ['French'], 'countries': ['Belgium', 'France', 'United Kingdom']}, {'title': 'The Sound of Christmas Review', 'genres': ['TV Movie', 'Drama'], 'languages': ['English'], 'countries': ['United States of America']}, {'title': 'The Inspection Review', 'genres': ['Drama'], 'languages': ['Arabic', 'Spanish', 'English'], 'countries': ['United States of America']}, {'title': 'Bones and All Review', 'genres': ['Drama', 'Horror', 'Romance'], 'languages': ['English'], 'countries': ['Italy', 'United States of America']}, {'title': 'My Policeman Review', 'genres': ['Drama', 'Romance'], 'languages': ['English'], 'countries': ['United Kingdom', 'United States of America']}, {'title': 'About Fate Review', 'genres': ['Romance', 'Comedy'], 'languages': ['English'], 'countries': ['United States of America']}, {'title': 'Waiting for Bojangles Review', 'genres': ['Drama', 'Comedy', 'Romance'], 'languages': ['English', 'French'], 'countries': ['France', 'United States of America']}, {'title': 'I Love My Dad Review', 'genres': ['Comedy'], 'languages': ['English'], 'countries': ['United States of America']}, {'title': 'A Love Song Review', 'genres': ['Romance', 'Drama'], 'languages': ['English', 'Spanish'], 'countries': ['Mexico']}, {'title': 'Alone Together Review', 'genres': ['Romance', 'Drama'], 'languages': ['English'], 'countries': ['United States of America']}, {'title': 'Art of Love Review', 'genres': ['Comedy'], 'languages': ['English'], 'countries': ['Switzerland', 'United Kingdom', 'United States of America']}, {'title': 'The Wheel Review', 'genres': ['Action', 'Science Fiction'], 'languages': ['English'], 'countries': ['Australia']}, {'title': 'Thor: Love and Thunder Review', 'genres': ['Fantasy', 'Action', 'Comedy'], 'languages': ['English'], 'countries': ['United States of  ...

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
# Preview the first five results in JSON format
print(json.dumps(tmdb_movies_list[:5], indent=4))
# Out:
# [
#     {
#         "title": "The Attachment Diaries Review",
#         "genres": [
#             "Drama",
#             "Mystery",
#             "Thriller",
#             "Horror"
#         ],
#         "languages": [
#             "Spanish"
#         ],
#         "countries": [
#             "Argentina"
#         ]
#     },
#     {
#         "title": "What Review",
#         "genres": [
#             "Comedy"
#         ],
#         "languages": [],
#         "countries": [
#             "United States of America"
#         ]
#     },
#     {
#         "title": "You Can Live Forever Review",
#         "genres": [
#             "Drama",
#             "Romance"
#         ],
#         "languages": [
#             "English",
#             "French"
#         ],
#         "countries": [
#             "Canada",
#             "United States of America"
#         ]
#     },
#     {
#         "title": "A Tourist Review",
#         "genres": [
#             "Romance",
#             "Comedy"
#         ],
#         "languages": [
#             "English",
#             "Vietnamese"
#         ],
#         "countries": [
#             "United States of America"
#         ]
#     },
#     {
#         "title": "Other People Review",
#         "genres": [
#             "Comedy",
#             "Drama"
#         ],
#         "languages": [
#             "English"
#         ],
#         "countries": [
#             "United States of America"
#         ]
#     }
# ]

# %%
# Convert the results to a DataFrame
import pandas as pd

# Convert the results to a DataFrame
tmdb_df = pd.DataFrame(tmdb_movies_list)

# Display the DataFrame
print(tmdb_df)
# Out:
#                                 title                              genres  \
# 0       The Attachment Diaries Review  [Drama, Mystery, Thriller, Horror]
# 1                         What Review                            [Comedy]
# 2         You Can Live Forever Review                    [Drama, Romance]
# 3                    A Tourist Review                   [Romance, Comedy]
# 4                 Other People Review                     [Comedy, Drama]
# ..                                ...                                 ...
# 191             The Other Half Review                    [Drama, Romance]
# 192     The Ottoman Lieutenant Review               [Romance, Drama, War]
# 193                 Review: It Review         [Horror, Mystery, Thriller]
# 194  Everybody Loves Somebody, Review                   [Romance, Comedy]
# 195                      Kedi, Review                           [Romance]
#
#                  languages                           countries
# 0                [Spanish]                         [Argentina]
# 1                       []          [United States of America]
# 2        [English, French]  [Canada, United States of America]
# 3    [English, Vietnamese]          [United States of America]
# 4                [English]          [United States of America]
# ..                     ...                                 ...
# 191              [English]                            [Canada]
# 192     [Turkish, English]  [Turkey, United States of America]
# 193  [English, Portuguese]          [United States of America]
# 194     [English, Spanish]                            [Mexico]
# 195                [Tamil]                             [India]
#
# [196 rows x 4 columns]

# %% [markdown]
# ### Merge and Clean the Data for Export

# %%
# Merge the New York Times reviews and TMDB DataFrames on title
# Merge the New York Times reviews and TMDB DataFrames on title

# Merge the New York Times reviews and TMDB DataFrames on the 'title' column
merged_df = pd.merge(df_reviews, tmdb_df, on='title', how='inner')

# Display the merged DataFrame
print(merged_df.head())
# Out:
#                                             headline  \
# 0        ‘The Attachment Diaries’ Review: Love, Sick
# 1  Review: ‘What’s Love Got to Do With It?’ Proba...
# 2  ‘You Can Live Forever’ Review: Do You Love Me ...
# 3  ‘A Tourist’s Guide to Love’ Review: A Wearying...
# 4     ‘Other People’s Children’ Review: True Romance
#
#                                                  url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/what...
# 2  https://www.nytimes.com/2023/05/04/movies/you-...
# 3  https://www.nytimes.com/2023/04/21/movies/a-to...
# 4  https://www.nytimes.com/2023/04/20/movies/othe...
#
#                            title                              genres  \
# 0  The Attachment Diaries Review  [Drama, Mystery, Thriller, Horror]
# 1                    What Review                            [Comedy]
# 2    You Can Live Forever Review                    [Drama, Romance]
# 3               A Tourist Review                   [Romance, Comedy]
# 4            Other People Review                     [Comedy, Drama]
#
#                languages                           countries
# 0              [Spanish]                         [Argentina]
# 1                     []          [United States of America]
# 2      [English, French]  [Canada, United States of America]
# 3  [English, Vietnamese]          [United States of America]
# 4              [English]          [United States of America]

# %%
# Remove list brackets and quotation marks on the columns containing lists
# Create a list of the columns that need fixing


# Create a list of characters to remove


# Loop through the list of columns to fix

    # Convert the column to type 'str'


    # Loop through characters to remove


# Display the fixed DataFrame

# Create a list of the columns that need fixing
columns_to_fix = ['genres', 'languages', 'countries']

# Create a list of characters to remove
characters_to_remove = ['[', ']', "'"]

# Loop through the list of columns to fix
for column in columns_to_fix:
    # Convert the column to type 'str'
    merged_df[column] = merged_df[column].astype(str)
    
    # Loop through characters to remove
    for char in characters_to_remove:
        # Remove the character from the string using the Pandas str.replace() method
        merged_df[column] = merged_df[column].str.replace(char, '')

# Display the fixed DataFrame
print(merged_df.head())
# Out:
#                                             headline  \
# 0        ‘The Attachment Diaries’ Review: Love, Sick
# 1  Review: ‘What’s Love Got to Do With It?’ Proba...
# 2  ‘You Can Live Forever’ Review: Do You Love Me ...
# 3  ‘A Tourist’s Guide to Love’ Review: A Wearying...
# 4     ‘Other People’s Children’ Review: True Romance
#
#                                                  url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/what...
# 2  https://www.nytimes.com/2023/05/04/movies/you-...
# 3  https://www.nytimes.com/2023/04/21/movies/a-to...
# 4  https://www.nytimes.com/2023/04/20/movies/othe...
#
#                            title                            genres  \
# 0  The Attachment Diaries Review  Drama, Mystery, Thriller, Horror
# 1                    What Review                            Comedy
# 2    You Can Live Forever Review                    Drama, Romance
# 3               A Tourist Review                   Romance, Comedy
# 4            Other People Review                     Comedy, Drama
#
#              languages                         countries
# 0              Spanish                         Argentina
# 1                               United States of America
# 2      English, French  Canada, United States of America
# 3  English, Vietnamese          United States of America
# 4              English          United States of America

# %%
# Drop "byline.person" column
# Check the column names in the DataFrame
# Drop the correct column
# Print the column names
print(df_reviews.columns)
# Out:
# Index(['headline', 'url', 'title'], dtype='object')

# %%
# Delete duplicate rows and reset index
# Delete duplicate rows and reset index
df_reviews.drop_duplicates(inplace=True)
df_reviews.reset_index(drop=True, inplace=True)

# Display the updated DataFrame
print(df_reviews.head())
# Out:
#                                             headline  \
# 0        ‘The Attachment Diaries’ Review: Love, Sick
# 1  Review: ‘What’s Love Got to Do With It?’ Proba...
# 2  ‘You Can Live Forever’ Review: Do You Love Me ...
# 3  ‘A Tourist’s Guide to Love’ Review: A Wearying...
# 4     ‘Other People’s Children’ Review: True Romance
#
#                                                  url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/what...
# 2  https://www.nytimes.com/2023/05/04/movies/you-...
# 3  https://www.nytimes.com/2023/04/21/movies/a-to...
# 4  https://www.nytimes.com/2023/04/20/movies/othe...
#
#                            title
# 0  The Attachment Diaries Review
# 1                    What Review
# 2    You Can Live Forever Review
# 3               A Tourist Review
# 4            Other People Review

# %%
# Export data to CSV without the index
# Export data to CSV without the index
df_reviews.to_csv('nytimes_movie_reviews_clean.csv', index=False)
